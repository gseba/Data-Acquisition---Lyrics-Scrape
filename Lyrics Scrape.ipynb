# %% [markdown]
# # ADS 509 Module 1: APIs and Web Scraping
#
# This notebook has two parts. In the first part, you will scrape lyrics from AZLyrics.com. In the second part, you'll run code that verifies the completeness of your data pull.
#
# For this assignment you have chosen two musical artists who have at least 20 songs with lyrics on AZLyrics.com. We start with pulling some information and analyzing them.

# %% [markdown]
# ## General Assignment Instructions
#
# These instructions are included in every assignment, to remind you of the coding standards for the class. Feel free to delete this cell after reading it.
#
# One sign of mature code is conforming to a style guide. We recommend the [Google Python Style Guide](https://google.github.io/styleguide/pyguide.html). If you use a different style guide, please include a cell with a link.
#
# Your code should be relatively easy-to-read, sensibly commented, and clean. Writing code is a messy process, so please be sure to edit your final submission. Remove any cells that are not needed or parts of cells that contain unnecessary code. Remove inessential `import` statements and make sure that all such statements are moved into the designated cell.
#
# Make use of non-code cells for written commentary. These cells should be grammatical and clearly written. In some of these cells you will have questions to answer. The questions will be marked by a "Q:" and will have a corresponding "A:" spot for you. *Make sure to answer every question marked with a `Q:` for full credit.*

# %% [markdown]
# # Importing Libraries

# %%
import os
import datetime
import re

# for the lyrics scrape section
import requests
import time
from bs4 import BeautifulSoup
from collections import defaultdict, Counter
import random

# %%
# Use this cell for any import statements you add
import shutil

# %% [markdown]
# ---
#
# # Lyrics Scrape
#
# This section asks you to pull data by scraping www.AZLyrics.com. In the notebooks where you do that work you are asked to store the data in specific ways.

# %%
artists = {'alan':"https://www.azlyrics.com/j/jacksonal.html",
           'queen':"https://www.azlyrics.com/q/queen.html"} 
# we'll use this dictionary to hold both the artist name and the link on AZlyrics

# %% [markdown]
# ## A Note on Rate Limiting
#
# The lyrics site, www.azlyrics.com, does not have an explicit maximum on number of requests in any one time, but in our testing it appears that too many requests in too short a time will cause the site to stop returning lyrics pages. (Entertainingly, the page that gets returned seems to only have the song title to [a Tom Jones song](https://www.azlyrics.com/lyrics/tomjones/itsnotunusual.html).)
#
# Whenever you call `requests.get` to retrieve a page, put a `time.sleep(5 + 10*random.random())` on the next line. This will help you not to get blocked. If you _do_ get blocked, which you can identify if the returned pages are not correct, just request a lyrics page through your browser. You'll be asked to perform a CAPTCHA and then your requests should start working again.
#
# ## Part 1: Finding Links to Songs Lyrics
#
# That general artist page has a list of all songs for that artist with links to the individual song pages.
#
# Q: Take a look at the `robots.txt` page on www.azlyrics.com. (You can read more about these pages [here](https://developers.google.com/search/docs/advanced/robots/intro).) Is the scraping we are about to do allowed or disallowed by this page? How do you know?
#
# ***A: Scraping the artist pages (e.g., https://www.azlyrics.com/q/queen.html and https://www.azlyrics.com/j/jacksonal.html) is allowed according to the `robots.txt` file (https://www.azlyrics.com/robots.txt) because these pages are not in the disallowed directories `/lyricsdb/` or `/song/`. The individual lyrics pages contain `/lyrics/` in the URL, in the following format (e.g., `https://---/lyrics/jacksonal/---.html`), which is not explicitly disallowed in the `robots.txt` file.***

# %% [markdown]
# ### Compile all of the URLs for the song lyrics available for each artist identified above

# %%
# Let's set up a dictionary of lists to hold our links
lyrics_pages = defaultdict(list)

for artist, artist_page in artists.items():
    # request the page and sleep
    r = requests.get(artist_page)
    time.sleep(5 + 10*random.random())

    # Parse the HTML content of the page
    soup = BeautifulSoup(r.content, 'html.parser')

    # Find all anchor tags with href attributes in the parsed HTML
    for link in soup.find_all('a', href=True):
        url = link['href'] 
    # Append full lyrics URL link (value) to each Artist (key) in the dictionary
        if url.startswith("/lyrics/"): # Returns boolean value
            full_url = "https://www.azlyrics.com" + url
            lyrics_pages[artist].append(full_url)

# Print the 'value' (link) for each key (Artist) in the dictionary of lists  
for artist, links in lyrics_pages.items():
    print(f"Lyrics pages for {artist}:")
    for link in links:
        print(link)
# Out:
# Lyrics pages for alan:
# https://www.azlyrics.com/lyrics/alanjackson/aintyourmemorygotnoprideatall.html
# https://www.azlyrics.com/lyrics/alanjackson/justforgetitson.html
# https://www.azlyrics.com/lyrics/alanjackson/merleandgeorge.html
# https://www.azlyrics.com/lyrics/alanjackson/donttouchme.html
# https://www.azlyrics.com/lyrics/alanjackson/breakoutthegoodstuff.html
# https://www.azlyrics.com/lyrics/alanjackson/thestealofthenight.html
# https://www.azlyrics.com/lyrics/alanjackson/whenthecatgoesout.html
# https://www.azlyrics.com/lyrics/alanjackson/icouldntcaremore.html
# https://www.azlyrics.com/lyrics/alanjackson/theycallmeaplayboy.html
# https://www.azlyrics.com/lyrics/alanjackson/wleeodanielandthelightcrustdoughboys.html
# https://www.azlyrics.com/lyrics/alanjackson/yourenotdrinkingenough.html
# https://www.azlyrics.com/lyrics/alanjackson/aceofhearts.html
# https://www.azlyrics.com/lyrics/alanjackson/hereintherealworld.html
# https://www.azlyrics.com/lyrics/alanjackson/bluebloodedwoman.html
# https://www.azlyrics.com/lyrics/alanjackson/wanted.html
# https://www.azlyrics.com/lyrics/alanjackson/chasinthatneonrainbow.html
# https://www.azlyrics.com/lyrics/alanjackson/shedontgettheblues.html
# https://www.azlyrics.com/lyrics/alanjackson/idloveyoualloveragain.html
# https://www.azlyrics.com/lyrics/alanjackson/dogriverblues.html
# https://www.azlyrics.com/lyrics/alanjackson/home.html
# https://www.azlyrics.com/lyrics/alanjackson/shortsweetride.html
# https://www.azlyrics.com/lyrics/alanjackson/dontrockthejukebox.html
# https://www.azlyrics.com/lyrics/alanjackson/thatsallineedtoknow.html
# https://www.azlyrics.com/lyrics/alanjackson/dallas.html
# https://www.azlyrics.com/lyrics/alanjackson/midnightinmontgomery.html
# https://www.azlyrics.com/lyrics/alanjackson/lovesgotaholdonyou.html
# https://www.azlyrics.com/lyrics/alanjackson/someday.html
# https://www.azlyrics.com/lyrics/alanjackson/justplayinpossum.html
# https://www.azlyrics.com/lyrics/alanjackson/fromadistance.html
# https://www.azlyrics.com/lyrics/alanjackson/walkintheflooroverme.html
# https://www.azlyrics.com/lyrics/alanjackson/workingclasshero.html
# https://www.azlyrics.com/lyrics/alanjackson/chattahoochee.html
# https://www.azlyrics.com/lyrics/alanjackson/shesgottherhythmandigottheblues.html
# https://www.azlyrics.com/lyrics/alanjackson/tonighticlimbedthewall.html
# https://www.azlyrics.com/lyrics/alanjackson/idontneedtheboozetogetabuzzon.html
# https://www.azlyrics.com/lyrics/alanjackson/whosaysyoucanthaveitall.html
# https://www.azlyrics.com/lyrics/alanjackson/uptomyearsintears.html
# https://www.azlyrics.com/lyrics/alanjackson/tropicaldepression.html
# https://www.azlyrics.com/lyrics/alanjackson/shelikesittoo.html
# https://www.azlyrics.com/lyrics/alanjackson/ifitaintonethingitsyou.html
# https://www.azlyrics.com/lyrics/alanjackson/mercuryblues.html
# https://www.azlyrics.com/lyrics/alanjackson/honkytonkchristmas.html
# https://www.azlyrics.com/lyrics/alanjackson/theangelscried.html
# https://www.azlyrics.com/lyrics/alanjackson/ifwemakeitthroughdecember.html
# https://www.azlyrics.com/lyrics/alanjackson/ifyoudontwannaseesantaclauscry.html
# https://www.azlyrics.com/lyrics/alanjackson/ionlywantyouforchristmas.html
# https://www.azlyrics.com/lyrics/alanjackson/merrychristmastome.html
# https://www.azlyrics.com/lyrics/alanjackson/ahollyjollychristmas.html
# https://www.azlyrics.com/lyrics/alanjackson/theresanewkidintown.html
# https://www.azlyrics.com/lyrics/alanjackson/santasgonnacomeinapickuptruck.html
# https://www.azlyrics.com/lyrics/alanjackson/pleasedaddydontgetdrunkthischristmas.html
# https://www.azlyrics.com/lyrics/alanjackson/summertimeblues.html
# https://www.azlyrics.com/lyrics/alanjackson/livinonlove.html
# https://www.azlyrics.com/lyrics/alanjackson/holeinthewall.html
# https://www.azlyrics.com/lyrics/alanjackson/gonecountry.html
# https://www.azlyrics.com/lyrics/alanjackson/whoiam.html
# https://www.azlyrics.com/lyrics/alanjackson/youcantgiveuponlove.html
# https://www.azlyrics.com/lyrics/alanjackson/idontevenknowyourname.html
# https://www.azlyrics.com/lyrics/alanjackson/songforthelife.html
# https://www.azlyrics.com/lyrics/alanjackson/thankgodfortheradio.html
# https://www.azlyrics.com/lyrics/alanjackson/allamericancountryboy.html
# https://www.azlyrics.com/lyrics/alanjackson/jobdescription.html
# https://www.azlyrics.com/lyrics/alanjackson/ifihadyou.html
# https://www.azlyrics.com/lyrics/alanjackson/letsgetbacktomeandyou.html
# https://www.azlyrics.com/lyrics/alanjackson/littlebitty.html
# https://www.azlyrics.com/lyrics/alanjackson/everythingilove.html
# https://www.azlyrics.com/lyrics/alanjackson/buickstothemoon.html
# https://www.azlyrics.com/lyrics/alanjackson/betweenthedevilandme.html
# https://www.azlyrics.com/lyrics/alanjackson/theregoes.html
# https://www.azlyrics.com/lyrics/alanjackson/ahousewithnocurtains.html
# https://www.azlyrics.com/lyrics/alanjackson/whoscheatinwho.html
# https://www.azlyrics.com/lyrics/alanjackson/walkontherocks.html
# https://www.azlyrics.com/lyrics/alanjackson/mustvehadaball.html
# https://www.azlyrics.com/lyrics/alanjackson/itstimeyoulearnedaboutgoodbye.html
# https://www.azlyrics.com/lyrics/alanjackson/rightonthemoney.html
# https://www.azlyrics.com/lyrics/alanjackson/gonecrazy.html
# https://www.azlyrics.com/lyrics/alanjackson/littleman.html
# https://www.azlyrics.com/lyrics/alanjackson/whatadayyesterdaywas.html
# https://www.azlyrics.com/lyrics/alanjackson/hurtincomeseasy.html
# https://www.azlyrics.com/lyrics/alanjackson/illgoonlovingyou.html
# https://www.azlyrics.com/lyrics/alanjackson/anothergoodreason.html
# https://www.azlyrics.com/lyrics/alanjackson/womanslove.html
# https://www.azlyrics.com/lyrics/alanjackson/dancinallaroundit.html
# https://www.azlyrics.com/lyrics/alanjackson/amarillo.html
# https://www.azlyrics.com/lyrics/alanjackson/popatop.html
# https://www.azlyrics.com/lyrics/alanjackson/farewellparty.html
# https://www.azlyrics.com/lyrics/alanjackson/kissanangelgoodmornin.html
# https://www.azlyrics.com/lyrics/alanjackson/rightinthepalmofyourhand.html
# https://www.azlyrics.com/lyrics/alanjackson/thebluesman.html
# https://www.azlyrics.com/lyrics/alanjackson/revenooerman.html
# https://www.azlyrics.com/lyrics/alanjackson/myownkindofhat.html
# https://www.azlyrics.com/lyrics/alanjackson/shejuststartedlikingcheatinsongs.html
# https://www.azlyrics.com/lyrics/alanjackson/thewayiam.html
# https://www.azlyrics.com/lyrics/alanjackson/itmustbelove.html
# https://www.azlyrics.com/lyrics/alanjackson/onceyouvehadthebest.html
# https://www.azlyrics.com/lyrics/alanjackson/margaritaville.html
# https://www.azlyrics.com/lyrics/alanjackson/meatandpotatoman.html
# https://www.azlyrics.com/lyrics/alanjackson/whensomebodylovesyou.html
# https://www.azlyrics.com/lyrics/alanjackson/thethrillisback.html
# https://www.azlyrics.com/lyrics/alanjackson/wwwmemory.html
# https://www.azlyrics.com/lyrics/alanjackson/whereicomefrom.html
# https://www.azlyrics.com/lyrics/alanjackson/istillloveyou.html
# https://www.azlyrics.com/lyrics/alanjackson/lifeorlove.html
# https://www.azlyrics.com/lyrics/alanjackson/alovelikethat.html
# https://www.azlyrics.com/lyrics/alanjackson/itsalrighttobearedneck.html
# https://www.azlyrics.com/lyrics/alanjackson/maybeishouldstayhere.html
# https://www.azlyrics.com/lyrics/alanjackson/threeminutepositivenottoocountryuptempolovesong.html
# https://www.azlyrics.com/lyrics/alanjackson/drivefordaddygene.html
# https://www.azlyrics.com/lyrics/alanjackson/alittlebluerthanthat.html
# https://www.azlyrics.com/lyrics/alanjackson/bringonthenight.html
# https://www.azlyrics.com/lyrics/alanjackson/workinprogress.html
# https://www.azlyrics.com/lyrics/alanjackson/thesounds.html
# https://www.azlyrics.com/lyrics/alanjackson/designateddrinker.html
# https://www.azlyrics.com/lyrics/alanjackson/wherewereyouwhentheworldstoppedturning.html
# https://www.azlyrics.com/lyrics/alanjackson/thatdbealright.html
# https://www.azlyrics.com/lyrics/alanjackson/onceinalifetimelove.html
# https://www.azlyrics.com/lyrics/alanjackson/whenlovecomesaround.html
# https://www.azlyrics.com/lyrics/alanjackson/islippedandfellinlove.html
# https://www.azlyrics.com/lyrics/alanjackson/firstlove.html
# https://www.azlyrics.com/lyrics/alanjackson/haveyourselfamerrylittlechristmas.html
# https://www.azlyrics.com/lyrics/alanjackson/winterwonderland.html
# https://www.azlyrics.com/lyrics/alanjackson/ocomeallyefaithful.html
# https://www.azlyrics.com/lyrics/alanjackson/santaclausiscomintotown.html
# https://www.azlyrics.com/lyrics/alanjackson/thechristmassong.html
# https://www.azlyrics.com/lyrics/alanjackson/silentnight.html
# https://www.azlyrics.com/lyrics/alanjackson/letitbechristmas.html
# https://www.azlyrics.com/lyrics/alanjackson/jinglebells.html
# https://www.azlyrics.com/lyrics/alanjackson/whitechristmas.html
# https://www.azlyrics.com/lyrics/alanjackson/silverbells.html
# https://www.azlyrics.com/lyrics/alanjackson/awayinamanger.html
# https://www.azlyrics.com/lyrics/alanjackson/toomuchofagoodthing.html
# https://www.azlyrics.com/lyrics/alanjackson/rainydayinjune.html
# https://www.azlyrics.com/lyrics/alanjackson/usatoday.html
# https://www.azlyrics.com/lyrics/alanjackson/iflovewasariver.html
# https://www.azlyrics.com/lyrics/alanjackson/iffrenchfrieswerefatfree.html
# https://www.azlyrics.com/lyrics/alanjackson/youdonthavetopaintmeapicture.html
# https://www.azlyrics.com/lyrics/alanjackson/thereyago.html
# https://www.azlyrics.com/lyrics/alanjackson/thetalkinsongrepairblues.html
# https://www.azlyrics.com/lyrics/alanjackson/strongenough.html
# https://www.azlyrics.com/lyrics/alanjackson/mondaymorningchurch.html
# https://www.azlyrics.com/lyrics/alanjackson/burninthehonkytonksdown.html
# https://www.azlyrics.com/lyrics/alanjackson/todowhatido.html
# https://www.azlyrics.com/lyrics/alanjackson/blessedassurance.html
# https://www.azlyrics.com/lyrics/alanjackson/softlyandtenderly.html
# https://www.azlyrics.com/lyrics/alanjackson/ilovetotellthestory.html
# https://www.azlyrics.com/lyrics/alanjackson/whenweallgettoheaven.html
# https://www.azlyrics.com/lyrics/alanjackson/tissosweettotrustinjesus.html
# https://www.azlyrics.com/lyrics/alanjackson/inthegarden.html
# https://www.azlyrics.com/lyrics/alanjackson/areyouwashedintheblood.html
# https://www.azlyrics.com/lyrics/alanjackson/illflyaway.html
# https://www.azlyrics.com/lyrics/alanjackson/whatafriendwehaveinjesus.html
# https://www.azlyrics.com/lyrics/alanjackson/standingonthepromises.html
# https://www.azlyrics.com/lyrics/alanjackson/turnyoureyesuponjesus.html
# https://www.azlyrics.com/lyrics/alanjackson/leaningontheeverlastingarms.html
# https://www.azlyrics.com/lyrics/alanjackson/theoldruggedcross.html
# https://www.azlyrics.com/lyrics/alanjackson/howgreatthouart.html
# https://www.azlyrics.com/lyrics/alanjackson/iwanttostrolloverheavenwithyou.html
# https://www.azlyrics.com/lyrics/alanjackson/anywhereonearthyouare.html
# https://www.azlyrics.com/lyrics/alanjackson/goodimitationoftheblues.html
# https://www.azlyrics.com/lyrics/alanjackson/likeredonarose.html
# https://www.azlyrics.com/lyrics/alanjackson/nobodysaidthatitwouldbeeasy.html
# https://www.azlyrics.com/lyrics/alanjackson/dontchangeonme.html
# https://www.azlyrics.com/lyrics/alanjackson/thefireflyssong.html
# https://www.azlyrics.com/lyrics/alanjackson/waitaminute.html
# https://www.azlyrics.com/lyrics/alanjackson/haditnotbeenyou.html
# https://www.azlyrics.com/lyrics/alanjackson/awomanslove.html
# https://www.azlyrics.com/lyrics/alanjackson/dontaskwhy.html
# https://www.azlyrics.com/lyrics/alanjackson/aslovelyasyou.html
# https://www.azlyrics.com/lyrics/alanjackson/wheredoigofromhereatruckerssong.html
# https://www.azlyrics.com/lyrics/alanjackson/bluebird.html
# https://www.azlyrics.com/lyrics/alanjackson/goodtime.html
# https://www.azlyrics.com/lyrics/alanjackson/smalltownsouthernman.html
# https://www.azlyrics.com/lyrics/alanjackson/iwishicouldbackup.html
# https://www.azlyrics.com/lyrics/alanjackson/countryboy.html
# https://www.azlyrics.com/lyrics/alanjackson/rightwhereiwantyou.html
# https://www.azlyrics.com/lyrics/alanjackson/1976.html
# https://www.azlyrics.com/lyrics/alanjackson/whenthelovefactorshigh.html
# https://www.azlyrics.com/lyrics/alanjackson/longlongway.html
# https://www.azlyrics.com/lyrics/alanjackson/sissyssong.html
# https://www.azlyrics.com/lyrics/alanjackson/istilllikebologna.html
# https://www.azlyrics.com/lyrics/alanjackson/neverlovedbefore.html
# https://www.azlyrics.com/lyrics/alanjackson/nothinglefttodo.html
# https://www.azlyrics.com/lyrics/alanjackson/listentoyoursenses.html
# https://www.azlyrics.com/lyrics/alanjackson/thistime.html
# https://www.azlyrics.com/lyrics/alanjackson/laidbacknlowkey.html
# https://www.azlyrics.com/lyrics/alanjackson/ifyouwanttomakemehappy.html
# https://www.azlyrics.com/lyrics/alanjackson/ifjesuswalkedtheworldtoday.html
# https://www.azlyrics.com/lyrics/alanjackson/hardhatandahammer.html
# https://www.azlyrics.com/lyrics/alanjackson/everynowandthen.html
# https://www.azlyrics.com/lyrics/alanjackson/after17.html
# https://www.azlyrics.com/lyrics/alanjackson/itsjustthatway.html
# https://www.azlyrics.com/lyrics/alanjackson/freighttrain.html
# https://www.azlyrics.com/lyrics/alanjackson/taillightsblue.html
# https://www.azlyrics.com/lyrics/alanjackson/icouldgetusedtothislovinthing.html
# https://www.azlyrics.com/lyrics/alanjackson/tilltheend.html
# https://www.azlyrics.com/lyrics/alanjackson/thatswhereibelong.html
# https://www.azlyrics.com/lyrics/alanjackson/biggreeneyes.html
# https://www.azlyrics.com/lyrics/alanjackson/trueloveisagoldenring.html
# https://www.azlyrics.com/lyrics/alanjackson/thebestkeepsgettingbetter.html
# https://www.azlyrics.com/lyrics/alanjackson/gonnacomebackasacountrysong.html
# https://www.azlyrics.com/lyrics/alanjackson/yougoyourway.html
# https://www.azlyrics.com/lyrics/alanjackson/everythingbutthewings.html
# https://www.azlyrics.com/lyrics/alanjackson/talkischeap.html
# https://www.azlyrics.com/lyrics/alanjackson/soyoudonthavetolovemeanymore.html
# https://www.azlyrics.com/lyrics/alanjackson/lookherintheeyeandlie.html
# https://www.azlyrics.com/lyrics/alanjackson/dixiehighway.html
# https://www.azlyrics.com/lyrics/alanjackson/shedontgethigh.html
# https://www.azlyrics.com/lyrics/alanjackson/herlifesasong.html
# https://www.azlyrics.com/lyrics/alanjackson/nothinfancy.html
# https://www.azlyrics.com/lyrics/alanjackson/longwaytogo.html
# https://www.azlyrics.com/lyrics/alanjackson/lifekeepsbringingmedown.html
# https://www.azlyrics.com/lyrics/alanjackson/whenisawyouleavingfornisey.html
# https://www.azlyrics.com/lyrics/alanjackson/amazinggrace.html
# https://www.azlyrics.com/lyrics/alanjackson/helives.html
# https://www.azlyrics.com/lyrics/alanjackson/justasiam.html
# https://www.azlyrics.com/lyrics/alanjackson/loveliftedme.html
# https://www.azlyrics.com/lyrics/alanjackson/ohowilovejesus.html
# https://www.azlyrics.com/lyrics/alanjackson/onlytrusthim.html
# https://www.azlyrics.com/lyrics/alanjackson/thereispowerintheblood.html
# https://www.azlyrics.com/lyrics/alanjackson/preciousmemories.html
# https://www.azlyrics.com/lyrics/alanjackson/sweethourofprayer.html
# https://www.azlyrics.com/lyrics/alanjackson/whentherolliscalledupyonder.html
# https://www.azlyrics.com/lyrics/alanjackson/whereverheleadsillgo.html
# https://www.azlyrics.com/lyrics/alanjackson/itsallabouthim.html
# https://www.azlyrics.com/lyrics/alanjackson/thatstheway.html
# https://www.azlyrics.com/lyrics/alanjackson/longhardroad.html
# https://www.azlyrics.com/lyrics/alanjackson/mary.html
# https://www.azlyrics.com/lyrics/alanjackson/wildandblue.html
# https://www.azlyrics.com/lyrics/alanjackson/appalachianmountaingirl.html
# https://www.azlyrics.com/lyrics/alanjackson/aintgottroublenow.html
# https://www.azlyrics.com/lyrics/alanjackson/blueridgemountainsong.html
# https://www.azlyrics.com/lyrics/alanjackson/tiemedown.html
# https://www.azlyrics.com/lyrics/alanjackson/thereisatime.html
# https://www.azlyrics.com/lyrics/alanjackson/bluesideofheaven.html
# https://www.azlyrics.com/lyrics/alanjackson/letsgetbacktomeandyou.html
# https://www.azlyrics.com/lyrics/alanjackson/waybeyondtheblue.html
# https://www.azlyrics.com/lyrics/alanjackson/knewallalong.html
# https://www.azlyrics.com/lyrics/alanjackson/blacktop.html
# https://www.azlyrics.com/lyrics/alanjackson/bluemoonofkentucky.html
# https://www.azlyrics.com/lyrics/alanjackson/youcanalwayscomehome.html
# https://www.azlyrics.com/lyrics/alanjackson/youneverknow.html
# https://www.azlyrics.com/lyrics/alanjackson/angelsandalcohol.html
# https://www.azlyrics.com/lyrics/alanjackson/gonebeforeyoumetme.html
# https://www.azlyrics.com/lyrics/alanjackson/theoneyourewaitingon.html
# https://www.azlyrics.com/lyrics/alanjackson/jimandjackandhank.html
# https://www.azlyrics.com/lyrics/alanjackson/ileavealighton.html
# https://www.azlyrics.com/lyrics/alanjackson/flaws.html
# https://www.azlyrics.com/lyrics/alanjackson/whengodpaints.html
# https://www.azlyrics.com/lyrics/alanjackson/mexicotequilaandme.html
# https://www.azlyrics.com/lyrics/alanjackson/wherehaveyougone.html
# https://www.azlyrics.com/lyrics/alanjackson/wishfuldrinkin.html
# https://www.azlyrics.com/lyrics/alanjackson/icanbesomething.html
# https://www.azlyrics.com/lyrics/alanjackson/wherethecottonwoodgrows.html
# https://www.azlyrics.com/lyrics/alanjackson/waydowninmywhiskey.html
# https://www.azlyrics.com/lyrics/alanjackson/thingsthatmatter.html
# https://www.azlyrics.com/lyrics/alanjackson/livinonempty.html
# https://www.azlyrics.com/lyrics/alanjackson/youllalwaysbemybaby.html
# https://www.azlyrics.com/lyrics/alanjackson/whereherhearthasalwaysbeen.html
# https://www.azlyrics.com/lyrics/alanjackson/theboot.html
# https://www.azlyrics.com/lyrics/alanjackson/back.html
# https://www.azlyrics.com/lyrics/alanjackson/writeitinred.html
# https://www.azlyrics.com/lyrics/alanjackson/solatesosoon.html
# https://www.azlyrics.com/lyrics/alanjackson/thisheartofmine.html
# https://www.azlyrics.com/lyrics/alanjackson/amanwhonevercries.html
# https://www.azlyrics.com/lyrics/alanjackson/chain.html
# https://www.azlyrics.com/lyrics/alanjackson/iwastequila.html
# https://www.azlyrics.com/lyrics/alanjackson/idowrittenfordaughtersweddings.html
# https://www.azlyrics.com/lyrics/alanjackson/thatsthewaylovegoes.html
# https://www.azlyrics.com/lyrics/alanjackson/beer10.html
# https://www.azlyrics.com/lyrics/alanjackson/theolderiget.html
# https://www.azlyrics.com/lyrics/alanjackson/amillionwaystodie.html
# https://www.azlyrics.com/lyrics/alanjackson/assheswalkingaway.html
# https://www.azlyrics.com/lyrics/alanjackson/illtry.html
# https://www.azlyrics.com/lyrics/alanjackson/itsfiveoclocksomewhere.html
# https://www.azlyrics.com/lyrics/alanjackson/lookatme.html
# https://www.azlyrics.com/lyrics/alanjackson/racingthedark.html
# https://www.azlyrics.com/lyrics/alanjackson/rememberwhen.html
# https://www.azlyrics.com/lyrics/alanjackson/ringoffire.html
# https://www.azlyrics.com/lyrics/alanjackson/talltalltrees.html
# https://www.azlyrics.com/lyrics/alanjackson/youvebeenlonesometoo.html
# Lyrics pages for queen:
# https://www.azlyrics.com/lyrics/queen/keepyourselfalive.html
# https://www.azlyrics.com/lyrics/queen/doingallright.html
# https://www.azlyrics.com/lyrics/queen/greatkingrat.html
# https://www.azlyrics.com/lyrics/queen/myfairyking.html
# https://www.azlyrics.com/lyrics/queen/liar.html
# https://www.azlyrics.com/lyrics/queen/thenightcomesdown.html
# https://www.azlyrics.com/lyrics/queen/moderntimesrocknroll.html
# https://www.azlyrics.com/lyrics/queen/sonanddaughter.html
# https://www.azlyrics.com/lyrics/queen/jesus.html
# https://www.azlyrics.com/lyrics/queen/madtheswine.html
# https://www.azlyrics.com/lyrics/queen/fathertoson.html
# https://www.azlyrics.com/lyrics/queen/whitequeenasitbegan.html
# https://www.azlyrics.com/lyrics/queen/somedayoneday.html
# https://www.azlyrics.com/lyrics/queen/theloserintheend.html
# https://www.azlyrics.com/lyrics/queen/ogrebattle.html
# https://www.azlyrics.com/lyrics/queen/thefairyfellersmasterstroke.html
# https://www.azlyrics.com/lyrics/queen/nevermore.html
# https://www.azlyrics.com/lyrics/queen/themarchoftheblackqueen.html
# https://www.azlyrics.com/lyrics/queen/funnyhowloveis.html
# https://www.azlyrics.com/lyrics/queen/sevenseasofrhye.html
# https://www.azlyrics.com/lyrics/queen/seewhatafoolivebeen.html
# https://www.azlyrics.com/lyrics/queen/brightonrock.html
# https://www.azlyrics.com/lyrics/queen/killerqueen.html
# https://www.azlyrics.com/lyrics/queen/tenementfunster.html
# https://www.azlyrics.com/lyrics/queen/flickofthewrist.html
# https://www.azlyrics.com/lyrics/queen/lilyofthevalley.html
# https://www.azlyrics.com/lyrics/queen/nowimhere.html
# https://www.azlyrics.com/lyrics/queen/inthelapofthegods.html
# https://www.azlyrics.com/lyrics/queen/stonecoldcrazy.html
# https://www.azlyrics.com/lyrics/queen/dearfriends.html
# https://www.azlyrics.com/lyrics/queen/misfire.html
# https://www.azlyrics.com/lyrics/queen/bringbackthatleroybrown.html
# https://www.azlyrics.com/lyrics/queen/shemakesmestormtrooperinstilettoes.html
# https://www.azlyrics.com/lyrics/queen/inthelapofthegodsrevisited.html
# https://www.azlyrics.com/lyrics/queen/deathontwolegs.html
# https://www.azlyrics.com/lyrics/queen/lazingonasundayafternoon.html
# https://www.azlyrics.com/lyrics/queen/iminlovewithmycar.html
# https://www.azlyrics.com/lyrics/queen/youremybestfriend.html
# https://www.azlyrics.com/lyrics/queen/39.html
# https://www.azlyrics.com/lyrics/queen/sweetlady.html
# https://www.azlyrics.com/lyrics/queen/seasiderendezvous.html
# https://www.azlyrics.com/lyrics/queen/theprophetssong.html
# https://www.azlyrics.com/lyrics/queen/loveofmylife.html
# https://www.azlyrics.com/lyrics/queen/goodcompany.html
# https://www.azlyrics.com/lyrics/queen/bohemianrhapsody.html
# https://www.azlyrics.com/lyrics/queen/tieyourmotherdown.html
# https://www.azlyrics.com/lyrics/queen/youtakemybreathaway.html
# https://www.azlyrics.com/lyrics/queen/longaway.html
# https://www.azlyrics.com/lyrics/queen/themillionairewaltz.html
# https://www.azlyrics.com/lyrics/queen/youandi.html
# https://www.azlyrics.com/lyrics/queen/somebodytolove.html
# https://www.azlyrics.com/lyrics/queen/whiteman.html
# https://www.azlyrics.com/lyrics/queen/goodoldfashionedloverboy.html
# https://www.azlyrics.com/lyrics/queen/drowse.html
# https://www.azlyrics.com/lyrics/queen/teotorriateletusclingtogether.html
# https://www.azlyrics.com/lyrics/queen/wewillrockyou.html
# https://www.azlyrics.com/lyrics/queen/wearethechampions.html
# https://www.azlyrics.com/lyrics/queen/sheerheartattack.html
# https://www.azlyrics.com/lyrics/queen/alldeadalldead.html
# https://www.azlyrics.com/lyrics/queen/spreadyourwings.html
# https://www.azlyrics.com/lyrics/queen/fightfromtheinside.html
# https://www.azlyrics.com/lyrics/queen/getdownmakelove.html
# https://www.azlyrics.com/lyrics/queen/sleepingonthesidewalk.html
# https://www.azlyrics.com/lyrics/queen/whoneedsyou.html
# https://www.azlyrics.com/lyrics/queen/itslate.html
# https://www.azlyrics.com/lyrics/queen/mymelancholyblues.html
# https://www.azlyrics.com/lyrics/queen/alldeadalldeadhybridversion.html
# https://www.azlyrics.com/lyrics/queen/mustapha.html
# https://www.azlyrics.com/lyrics/queen/fatbottomedgirls.html
# https://www.azlyrics.com/lyrics/queen/jealousy.html
# https://www.azlyrics.com/lyrics/queen/bicyclerace.html
# https://www.azlyrics.com/lyrics/queen/ifyoucantbeatthem.html
# https://www.azlyrics.com/lyrics/queen/letmeentertainyou.html
# https://www.azlyrics.com/lyrics/queen/deadontime.html
# https://www.azlyrics.com/lyrics/queen/inonlysevendays.html
# https://www.azlyrics.com/lyrics/queen/dreamersball.html
# https://www.azlyrics.com/lyrics/queen/funit.html
# https://www.azlyrics.com/lyrics/queen/leavinghomeainteasy.html
# https://www.azlyrics.com/lyrics/queen/dontstopmenow.html
# https://www.azlyrics.com/lyrics/queen/moreofthatjazz.html
# https://www.azlyrics.com/lyrics/queen/playthegame.html
# https://www.azlyrics.com/lyrics/queen/dragonattack.html
# https://www.azlyrics.com/lyrics/queen/anotheronebitesthedust.html
# https://www.azlyrics.com/lyrics/queen/needyourlovingtonight.html
# https://www.azlyrics.com/lyrics/queen/crazylittlethingcalledlove.html
# https://www.azlyrics.com/lyrics/queen/rockitprimejive.html
# https://www.azlyrics.com/lyrics/queen/donttrysuicide.html
# https://www.azlyrics.com/lyrics/queen/sailawaysweetsistertothesisterineverhad.html
# https://www.azlyrics.com/lyrics/queen/comingsoon.html
# https://www.azlyrics.com/lyrics/queen/saveme.html
# https://www.azlyrics.com/lyrics/queen/stayingpower.html
# https://www.azlyrics.com/lyrics/queen/dancer.html
# https://www.azlyrics.com/lyrics/queen/backchat.html
# https://www.azlyrics.com/lyrics/queen/bodylanguage.html
# https://www.azlyrics.com/lyrics/queen/actionthisday.html
# https://www.azlyrics.com/lyrics/queen/putoutthefire.html
# https://www.azlyrics.com/lyrics/queen/lifeisrealsongforlennon.html
# https://www.azlyrics.com/lyrics/queen/callingallgirls.html
# https://www.azlyrics.com/lyrics/queen/laspalabrasdeamorthewordsoflove.html
# https://www.azlyrics.com/lyrics/queen/coolcat.html
# https://www.azlyrics.com/lyrics/queen/underpressure.html
# https://www.azlyrics.com/lyrics/queen/radiogaga.html
# https://www.azlyrics.com/lyrics/queen/tearitup.html
# https://www.azlyrics.com/lyrics/queen/itsahardlife.html
# https://www.azlyrics.com/lyrics/queen/manontheprowl.html
# https://www.azlyrics.com/lyrics/queen/machinesorbacktohumans.html
# https://www.azlyrics.com/lyrics/queen/iwanttobreakfree.html
# https://www.azlyrics.com/lyrics/queen/keeppassingtheopenwindows.html
# https://www.azlyrics.com/lyrics/queen/hammertofall.html
# https://www.azlyrics.com/lyrics/queen/isthistheworldwecreated.html
# https://www.azlyrics.com/lyrics/queen/igocrazy.html
# https://www.azlyrics.com/lyrics/queen/onevision.html
# https://www.azlyrics.com/lyrics/queen/akindofmagic.html
# https://www.azlyrics.com/lyrics/queen/oneyearoflove.html
# https://www.azlyrics.com/lyrics/queen/painissoclosetopleasure.html
# https://www.azlyrics.com/lyrics/queen/friendswillbefriends.html
# https://www.azlyrics.com/lyrics/queen/whowantstoliveforever.html
# https://www.azlyrics.com/lyrics/queen/gimmetheprize.html
# https://www.azlyrics.com/lyrics/queen/dontloseyourhead.html
# https://www.azlyrics.com/lyrics/queen/princesoftheuniverse.html
# https://www.azlyrics.com/lyrics/queen/party.html
# https://www.azlyrics.com/lyrics/queen/khashoggisship.html
# https://www.azlyrics.com/lyrics/queen/themiracle.html
# https://www.azlyrics.com/lyrics/queen/iwantitall.html
# https://www.azlyrics.com/lyrics/queen/theinvisibleman.html
# https://www.azlyrics.com/lyrics/queen/breakthru.html
# https://www.azlyrics.com/lyrics/queen/rainmustfall.html
# https://www.azlyrics.com/lyrics/queen/scandal.html
# https://www.azlyrics.com/lyrics/queen/mybabedoesme.html
# https://www.azlyrics.com/lyrics/queen/wasitallworthit.html
# https://www.azlyrics.com/lyrics/queen/hangoninthere.html
# https://www.azlyrics.com/lyrics/queen/hijackmyheart.html
# https://www.azlyrics.com/lyrics/queen/stealin.html
# https://www.azlyrics.com/lyrics/queen/innuendo.html
# https://www.azlyrics.com/lyrics/queen/imgoingslightlymad.html
# https://www.azlyrics.com/lyrics/queen/headlong.html
# https://www.azlyrics.com/lyrics/queen/icantlivewithyou.html
# https://www.azlyrics.com/lyrics/queen/donttrysohard.html
# https://www.azlyrics.com/lyrics/queen/ridethewildwind.html
# https://www.azlyrics.com/lyrics/queen/allgodspeople.html
# https://www.azlyrics.com/lyrics/queen/thesearethedaysofourlives.html
# https://www.azlyrics.com/lyrics/queen/delilah.html
# https://www.azlyrics.com/lyrics/queen/thehitman.html
# https://www.azlyrics.com/lyrics/queen/bijou.html
# https://www.azlyrics.com/lyrics/queen/theshowmustgoon.html
# https://www.azlyrics.com/lyrics/queen/itsabeautifulday.html
# https://www.azlyrics.com/lyrics/queen/madeinheaven.html
# https://www.azlyrics.com/lyrics/queen/letmelive.html
# https://www.azlyrics.com/lyrics/queen/motherlove.html
# https://www.azlyrics.com/lyrics/queen/mylifehasbeensaved.html
# https://www.azlyrics.com/lyrics/queen/iwasborntoloveyou.html
# https://www.azlyrics.com/lyrics/queen/heavenforeveryone.html
# https://www.azlyrics.com/lyrics/queen/toomuchlovewillkillyou.html
# https://www.azlyrics.com/lyrics/queen/youdontfoolme.html
# https://www.azlyrics.com/lyrics/queen/awinterstale.html
# https://www.azlyrics.com/lyrics/queen/itsabeautifuldayreprise.html
# https://www.azlyrics.com/lyrics/queen/yeah.html
# https://www.azlyrics.com/lyrics/queen/13.html
# https://www.azlyrics.com/lyrics/queen/cosmosrockin.html
# https://www.azlyrics.com/lyrics/queen/timetoshine.html
# https://www.azlyrics.com/lyrics/queen/stillburnin.html
# https://www.azlyrics.com/lyrics/queen/small.html
# https://www.azlyrics.com/lyrics/queen/warboys.html
# https://www.azlyrics.com/lyrics/queen/webelieve.html
# https://www.azlyrics.com/lyrics/queen/callme.html
# https://www.azlyrics.com/lyrics/queen/voodoo.html
# https://www.azlyrics.com/lyrics/queen/somethingsthatglitter.html
# https://www.azlyrics.com/lyrics/queen/clebrity.html
# https://www.azlyrics.com/lyrics/queen/throughthenight.html
# https://www.azlyrics.com/lyrics/queen/sayitsnottrue.html
# https://www.azlyrics.com/lyrics/queen/surfsupschoolsout.html
# https://www.azlyrics.com/lyrics/queen/smallreprise.html
# https://www.azlyrics.com/lyrics/queen/runaway.html
# https://www.azlyrics.com/lyrics/queen/fireandwater.html
# https://www.azlyrics.com/lyrics/queen/ahumanbody.html
# https://www.azlyrics.com/lyrics/queen/breakthrurealdrumsandbass.html
# https://www.azlyrics.com/lyrics/queen/dogwithabone.html
# https://www.azlyrics.com/lyrics/queen/faceitalone.html
# https://www.azlyrics.com/lyrics/queen/feelingsfeelings.html
# https://www.azlyrics.com/lyrics/queen/flash.html
# https://www.azlyrics.com/lyrics/queen/iguesswereallfallingoutdemo.html
# https://www.azlyrics.com/lyrics/queen/letmeinyourheartagain.html
# https://www.azlyrics.com/lyrics/queen/lostopportunity.html
# https://www.azlyrics.com/lyrics/queen/loveofmylifelive.html
# https://www.azlyrics.com/lyrics/queen/mybabylovesme.html
# https://www.azlyrics.com/lyrics/queen/noonebutyouonlythegooddieyoung.html
# https://www.azlyrics.com/lyrics/queen/rainmustfalldemo.html
# https://www.azlyrics.com/lyrics/queen/seewhatafoolivebeenbbcsessions.html
# https://www.azlyrics.com/lyrics/queen/seewhatafoolivebeenlive.html
# https://www.azlyrics.com/lyrics/queen/soulbrother.html
# https://www.azlyrics.com/lyrics/queen/thankgoditschristmas.html
# https://www.azlyrics.com/lyrics/queen/thehero.html
# https://www.azlyrics.com/lyrics/queen/waterdemo.html
# https://www.azlyrics.com/lyrics/queen/wearethechampions724741.html
# https://www.azlyrics.com/lyrics/queen/whenlovebreaksupdemo.html
# https://www.azlyrics.com/lyrics/queen/youarethechampions.html
# https://www.azlyrics.com/lyrics/queen/youknowyoubelongtome.html

# %% [markdown]
# Let's make sure we have enough lyrics pages to scrape.

# %%
for artist, lp in lyrics_pages.items() :
    assert(len(set(lp)) > 20)

# %%
# Let's see how long it's going to take to pull these lyrics 
# if we're waiting `5 + 10*random.random()` seconds 
for artist, links in lyrics_pages.items() : 
    print(f"For {artist} we have {len(links)}.")
    print(f"The full pull will take for this artist will take {round(len(links)*10/3600,2)} hours.")
# Out:
# For alan we have 280.
# The full pull will take for this artist will take 0.78 hours.
# For queen we have 197.
# The full pull will take for this artist will take 0.55 hours.

# %% [markdown]
# ## Part 2: Pulling Lyrics
#
# Now that we have the links to our lyrics pages, let's go scrape them! Here are the steps for this part.
#
# 1. Create an empty folder in our repo called "lyrics".
# 1. Iterate over the artists in `lyrics_pages`.
# 1. Create a subfolder in lyrics with the artist's name. For instance, if the artist was Cher you'd have `lyrics/cher/` in your repo.
# 1. Iterate over the pages.
# 1. Request the page and extract the lyrics from the returned HTML file using BeautifulSoup.
# 1. Use the function below, `generate_filename_from_url`, to create a filename based on the lyrics page, then write the lyrics to a text file with that name.

# %%
def generate_filename_from_url(link) :
    
    if not link :
        return None
    
    # drop the http or https and the html
    name = link.replace("https","").replace("http","")
    name = link.replace(".html","")

    name = name.replace("/lyrics/","")
    
    # Replace useless chareacters with UNDERSCORE
    name = name.replace("://","").replace(".","_").replace("/","_")
    
    # tack on .txt
    name = name + ".txt"
    
    return(name)

# %%
# Make the lyrics folder here. If you'd like to practice your programming, add functionality 
# that checks to see if the folder exists. If it does, then use shutil.rmtree to remove it and create a new one.

if os.path.isdir("lyrics") : 
    shutil.rmtree("lyrics/")

os.mkdir("lyrics")

# %% [markdown]
# ### Inspect page for structure

# %%
# Page URL
url = "https://www.azlyrics.com/lyrics/queen/thefairyfellersmasterstroke.html"

# Request the page
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Find all <div> elements on the page
divs = soup.find_all('div')

# Count the number of <div> elements
div_count = len(divs)

print(f"Total number of <div> elements: {div_count}")

# Print the content of each <div> with its index to verify
for index, div in enumerate(divs):
    print(f"Index {index}: {div.get_text(strip=True)[:100]}")

# %% [markdown]
# ### Scrape Lyric from Site and write to text files seprated by 'Artist' folders

# %%
url_stub = "https://www.azlyrics.com" 
start = time.time()

total_pages = 0 

for artist, pages in lyrics_pages.items():

    # 1. Build a subfolder for the artist
    artist_folder = os.path.join("lyrics", artist)
    if not os.path.exists(artist_folder):
        os.makedirs(artist_folder)
        
    # 2. Iterate over the lyrics pages
    for i, lyrics_page_url in enumerate(pages[:50]): # 50 songs for each artist
        try:
            # 3. Request the lyrics page. 
            time.sleep(5 + 10 * random.random())
            response = requests.get(lyrics_page_url)
            if response.status_code == 200:
                soup = BeautifulSoup(response.content, 'html.parser')
                
                # 4. Extract the title and lyrics from the page (div 24 based on above inspection)
                title = soup.find('title').get_text(strip=True)
                lyrics_div = soup.find_all('div')[24]
                lyrics = lyrics_div.get_text(separator="\n", strip=True)

                
                # 5. Use `generate_filename_from_url` to generate the filename. 
                filename = generate_filename_from_url(lyrics_page_url)  
                file_path = os.path.join(artist_folder, filename) 
                # Write out the title, two returns ('\n'), and the lyrics (in the text file in the folder)
                with open(file_path, 'w', encoding='utf-8') as f:
                    f.write(title + '\n\n') 
                    f.write(lyrics)
                                
                total_pages += 1 # update counter
                print(f'Successfully wrote lyrics for {title} to {file_path}')
            else: # Check if error is on our side or not 
                print(f'Failed to retrieve page: {lyrics_page_url}, Status code: {response.status_code}') 
                        
        except Exception as e: 
            print(f'An error occurred while processing {lyrics_page_url}: {e}')

end = time.time()
# Out:
# Successfully wrote lyrics for Alan Jackson - Ain't Your Memory Got No Pride At All Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_aintyourmemorygotnoprideatall.txt
# Successfully wrote lyrics for Alan Jackson - Just Forget It, Son Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_justforgetitson.txt
# Successfully wrote lyrics for Alan Jackson - Merle And George Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_merleandgeorge.txt
# Successfully wrote lyrics for Alan Jackson - Don't Touch Me Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_donttouchme.txt
# Successfully wrote lyrics for Alan Jackson - Break Out The Good Stuff Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_breakoutthegoodstuff.txt
# Successfully wrote lyrics for Alan Jackson - The Steal Of The Night Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_thestealofthenight.txt
# Successfully wrote lyrics for Alan Jackson - When The Cat Goes Out Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_whenthecatgoesout.txt
# Successfully wrote lyrics for Alan Jackson - I Couldn't Care More Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_icouldntcaremore.txt
# Successfully wrote lyrics for Alan Jackson - They Call Me A Playboy Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_theycallmeaplayboy.txt
# Successfully wrote lyrics for Alan Jackson - W. Lee O'Daniel And The Light Crust Dough Boys Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_wleeodanielandthelightcrustdoughboys.txt
# Successfully wrote lyrics for Alan Jackson - You're Not Drinking Enough Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_yourenotdrinkingenough.txt
# Successfully wrote lyrics for Alan Jackson - Ace Of Hearts Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_aceofhearts.txt
# Successfully wrote lyrics for Alan Jackson - Here In The Real World Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_hereintherealworld.txt
# Successfully wrote lyrics for Alan Jackson - Blue Blooded Woman Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_bluebloodedwoman.txt
# Successfully wrote lyrics for Alan Jackson - Wanted Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_wanted.txt
# Successfully wrote lyrics for Alan Jackson - Chasin' That Neon Rainbow Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_chasinthatneonrainbow.txt
# Successfully wrote lyrics for Alan Jackson - She Don't Get The Blues Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_shedontgettheblues.txt
# Successfully wrote lyrics for Alan Jackson - I'd Love You All Over Again Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_idloveyoualloveragain.txt
# Successfully wrote lyrics for Alan Jackson - Dog River Blues Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_dogriverblues.txt
# Successfully wrote lyrics for Alan Jackson - Home Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_home.txt
# Successfully wrote lyrics for Alan Jackson - Short Sweet Ride Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_shortsweetride.txt
# Successfully wrote lyrics for Alan Jackson - Don't Rock The Jukebox Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_dontrockthejukebox.txt
# Successfully wrote lyrics for Alan Jackson - That's All I Need To Know Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_thatsallineedtoknow.txt
# Successfully wrote lyrics for Alan Jackson - Dallas Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_dallas.txt
# Successfully wrote lyrics for Alan Jackson - Midnight In Montgomery Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_midnightinmontgomery.txt
# Successfully wrote lyrics for Alan Jackson - Love's Got A Hold On You Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_lovesgotaholdonyou.txt
# Successfully wrote lyrics for Alan Jackson - Someday Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_someday.txt
# Successfully wrote lyrics for Alan Jackson - Just Playin' Possum Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_justplayinpossum.txt
# Successfully wrote lyrics for Alan Jackson - From A Distance Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_fromadistance.txt
# Successfully wrote lyrics for Alan Jackson - Walkin' The Floor Over Me Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_walkintheflooroverme.txt
# Successfully wrote lyrics for Alan Jackson - Working Class Hero Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_workingclasshero.txt
# Successfully wrote lyrics for Alan Jackson - Chattahoochee Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_chattahoochee.txt
# Successfully wrote lyrics for Alan Jackson - She's Got The Rhythm (And I Got The Blues) Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_shesgottherhythmandigottheblues.txt
# Successfully wrote lyrics for Alan Jackson - Tonight I Climbed The Wall Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_tonighticlimbedthewall.txt
# Successfully wrote lyrics for Alan Jackson - I Don't Need The Booze (To Get A Buzz On) Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_idontneedtheboozetogetabuzzon.txt
# Successfully wrote lyrics for Alan Jackson - (Who Says) You Can't Have It All Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_whosaysyoucanthaveitall.txt
# Successfully wrote lyrics for Alan Jackson - Up To My Ears In Tears Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_uptomyearsintears.txt
# Successfully wrote lyrics for Alan Jackson - Tropical Depression Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_tropicaldepression.txt
# Successfully wrote lyrics for Alan Jackson - She Likes It Too Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_shelikesittoo.txt
# Successfully wrote lyrics for Alan Jackson - If It Ain't One Thing (It's You) Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_ifitaintonethingitsyou.txt
# Successfully wrote lyrics for Alan Jackson - Mercury Blues Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_mercuryblues.txt
# Successfully wrote lyrics for Alan Jackson - Honky Tonk Christmas Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_honkytonkchristmas.txt
# Successfully wrote lyrics for Alan Jackson - The Angels Cried Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_theangelscried.txt
# Successfully wrote lyrics for Alan Jackson - If We Make It Through December Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_ifwemakeitthroughdecember.txt
# Successfully wrote lyrics for Alan Jackson - If You Don't Wanna See Santa Claus Cry Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_ifyoudontwannaseesantaclauscry.txt
# Successfully wrote lyrics for Alan Jackson - I Only Want You For Christmas Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_ionlywantyouforchristmas.txt
# Successfully wrote lyrics for Alan Jackson - Merry Christmas To Me Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_merrychristmastome.txt
# Successfully wrote lyrics for Alan Jackson - A Holly Jolly Christmas Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_ahollyjollychristmas.txt
# Successfully wrote lyrics for Alan Jackson - There's A New Kid In Town Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_theresanewkidintown.txt
# Successfully wrote lyrics for Alan Jackson - Santa's Gonna Come In A Pickup Truck Lyrics | AZLyrics.com to lyrics\alan\httpswww_azlyrics_comalanjackson_santasgonnacomeinapickuptruck.txt
# Successfully wrote lyrics for Queen - Keep Yourself Alive Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_keepyourselfalive.txt
# Successfully wrote lyrics for Queen - Doing All Right Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_doingallright.txt
# Successfully wrote lyrics for Queen - Great King Rat Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_greatkingrat.txt
# Successfully wrote lyrics for Queen - My Fairy King Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_myfairyking.txt
# Successfully wrote lyrics for Queen - Liar Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_liar.txt
# Successfully wrote lyrics for Queen - The Night Comes Down Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_thenightcomesdown.txt
# Successfully wrote lyrics for Queen - Modern Times Rock 'N' Roll Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_moderntimesrocknroll.txt
# Successfully wrote lyrics for Queen - Son And Daughter Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_sonanddaughter.txt
# Successfully wrote lyrics for Queen - Jesus Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_jesus.txt
# Successfully wrote lyrics for Queen - Mad The Swine Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_madtheswine.txt
# Successfully wrote lyrics for Queen - Father To Son Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_fathertoson.txt
# Successfully wrote lyrics for Queen - White Queen (As It Began) Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_whitequeenasitbegan.txt
# Successfully wrote lyrics for Queen - Some Day One Day Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_somedayoneday.txt
# Successfully wrote lyrics for Queen - The Loser In The End Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_theloserintheend.txt
# Successfully wrote lyrics for Queen - Ogre Battle Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_ogrebattle.txt
# Successfully wrote lyrics for Queen - The Fairy Feller's Master-Stroke Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_thefairyfellersmasterstroke.txt
# Successfully wrote lyrics for Queen - Nevermore Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_nevermore.txt
# Successfully wrote lyrics for Queen - The March Of The Black Queen Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_themarchoftheblackqueen.txt
# Successfully wrote lyrics for Queen - Funny How Love Is Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_funnyhowloveis.txt
# Successfully wrote lyrics for Queen - Seven Seas Of Rhye Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_sevenseasofrhye.txt
# Successfully wrote lyrics for Queen - See What A Fool I've Been Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_seewhatafoolivebeen.txt
# Successfully wrote lyrics for Queen - Brighton Rock Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_brightonrock.txt
# Successfully wrote lyrics for Queen - Killer Queen Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_killerqueen.txt
# Successfully wrote lyrics for Queen - Tenement Funster Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_tenementfunster.txt
# Successfully wrote lyrics for Queen - Flick Of The Wrist Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_flickofthewrist.txt
# Successfully wrote lyrics for Queen - Lily Of The Valley Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_lilyofthevalley.txt
# Successfully wrote lyrics for Queen - Now I'm Here Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_nowimhere.txt
# Successfully wrote lyrics for Queen - In The Lap Of The Gods Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_inthelapofthegods.txt
# Successfully wrote lyrics for Queen - Stone Cold Crazy Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_stonecoldcrazy.txt
# Successfully wrote lyrics for Queen - Dear Friends Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_dearfriends.txt
# Successfully wrote lyrics for Queen - Misfire Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_misfire.txt
# Successfully wrote lyrics for Queen - Bring Back That Leroy Brown Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_bringbackthatleroybrown.txt
# Successfully wrote lyrics for Queen - She Makes Me (Stormtrooper In Stilettoes) Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_shemakesmestormtrooperinstilettoes.txt
# Successfully wrote lyrics for Queen - In The Lap Of The Gods (Revisited) Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_inthelapofthegodsrevisited.txt
# Successfully wrote lyrics for Queen - Death On Two Legs Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_deathontwolegs.txt
# Successfully wrote lyrics for Queen - Lazing On A Sunday Afternoon Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_lazingonasundayafternoon.txt
# Successfully wrote lyrics for Queen - I'm In Love With My Car Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_iminlovewithmycar.txt
# Successfully wrote lyrics for Queen - You're My Best Friend Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_youremybestfriend.txt
# Successfully wrote lyrics for Queen - '39 Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_39.txt
# Successfully wrote lyrics for Queen - Sweet Lady Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_sweetlady.txt
# Successfully wrote lyrics for Queen - Seaside Rendezvous Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_seasiderendezvous.txt
# Successfully wrote lyrics for Queen - The Prophet's Song Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_theprophetssong.txt
# Successfully wrote lyrics for Queen - Love Of My Life Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_loveofmylife.txt
# Successfully wrote lyrics for Queen - Good Company Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_goodcompany.txt
# Successfully wrote lyrics for Queen - Bohemian Rhapsody Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_bohemianrhapsody.txt
# Successfully wrote lyrics for Queen - Tie Your Mother Down Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_tieyourmotherdown.txt
# Successfully wrote lyrics for Queen - You Take My Breath Away Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_youtakemybreathaway.txt
# Successfully wrote lyrics for Queen - Long Away Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_longaway.txt
# Successfully wrote lyrics for Queen - The Millionaire Waltz Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_themillionairewaltz.txt
# Successfully wrote lyrics for Queen - You And I Lyrics | AZLyrics.com to lyrics\queen\httpswww_azlyrics_comqueen_youandi.txt

# %%
print(f"Total run time was {round((time.time() - start)/3600,2)} hours.")
# Out:
# Total run time was 0.3 hours.

# %% [markdown]
# ---
#
# # Evaluation
#
# This assignment asks you to pull data by scraping www.AZLyrics.com.  After you have finished the above sections , run all the cells in this notebook. Print this to PDF and submit it, per the instructions.

# %%
# Simple word extractor from Peter Norvig: https://norvig.com/spell-correct.html
def words(text): 
    return re.findall(r'\w+', text.lower())

# %% [markdown]
# ## Checking Lyrics
#
# The output from your lyrics scrape should be stored in files located in this path from the directory:
# `/lyrics/[Artist Name]/[filename from URL]`. This code summarizes the information at a high level to help the instructor evaluate your work.

# %%
artist_folders = os.listdir("lyrics/")
artist_folders = [f for f in artist_folders if os.path.isdir("lyrics/" + f)]

for artist in artist_folders : 
    artist_files = os.listdir("lyrics/" + artist)
    artist_files = [f for f in artist_files if 'txt' in f or 'csv' in f or 'tsv' in f]

    print(f"For {artist} we have {len(artist_files)} files.")

    artist_words = []

    for f_name in artist_files : 
        with open("lyrics/" + artist + "/" + f_name) as infile : 
            artist_words.extend(words(infile.read()))

            
    print(f"For {artist} we have roughly {len(artist_words)} words, {len(set(artist_words))} are unique.")
# Out:
# For alan we have 50 files.
# For alan we have roughly 10971 words, 1319 are unique.
# For queen we have 50 files.
# For queen we have roughly 11885 words, 1698 are unique.

# %% [markdown]
# <center><b>References:</b></center>
#
#
# - Weber, B. (2023, August 1). Python enumerate(): *Simplify loops that need counters.* Real Python. https://realpython.com/python-enumerate/
# - Sulcas, A. (2023, June 6). *Beautiful soup tutorial - how to Parse web data with python.* Oxylabs. https://oxylabs.io/blog/beautiful-soup-parsing-tutorial
# - ScrapFly Blog. (2024, August 22). *How to Parse Web Data with Python and Beautifulsoup.* ScrapFly Blog. https://scrapfly.io/blog/web-scraping-with-python-beautifulsoup/
# - Sanchhaya Education Private Limited. (2024, July 7). *Python | os.path.join() method.* GeeksforGeeks. https://www.geeksforgeeks.org/python-os-path-join-method/
# - Python Software Foundation. (n.d.). *os.path — Common pathname manipulations.* Python documentation. https://docs.python.org/3/library/os.path.html
# - Python Software Foundation. (n.d.). *Built-in functions - Open.* Python documentation. https://docs.python.org/3/library/functions.html#open
# - Python Software Foundation. (n.d.). *Built-in functions - Enumerate.* Python documentation. https://docs.python.org/3/library/functions.html#enumerate
# - OpenAI. (2023). ChatGPT (September 9 version) [Large language model]. https://chat.openai.com/
# - Mozilla Developer Network. (n.d.). *String.prototype.startsWith().* MDN Web Docs. https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/String/startsWith
# - Fawole, J. (2024, May 27). *How to Scrape Web Data Using Requests and BeautifulSoup.* ScraperAPI. https://www.scraperapi.com/blog/beautifulsoup-and-requests/
# - Awan, A. A. (2023, February 24). *Exception & Error Handling in python: Tutorial by datacamp.* DataCamp. https://www.datacamp.com/tutorial/exception-handling-python
# - Albrecht, J., Ramachandran, S., & Winkler, C. (2020). *Blueprints for text analytics using Python.* O'Reilly.
# - *Python File write() Method.* W3Schools Online Web Tutorials. (n.d.). https://www.w3schools.com/python/ref_file_write.asp
